# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing              import MinMaxScaler 
from sklearn.model_selection            import train_test_split, ShuffleSplit
from sklearn.model_selection            import GridSearchCV
from sklearn.ensemble                   import RandomForestRegressor
from sklearn.ensemble                   import GradientBoostingRegressor
from sklearn.gaussian_process           import GaussianProcessRegressor  
from sklearn.metrics                    import mean_absolute_error

# %%
x_train_p =r"E:\T&T\dengue_features_train.csv"
y_train_p =r"E:\T&T\dengue_labels_train.csv"
x_test_p =r"E:\T&T\dengue_features_test.csv"
y_test_p =r""

# %%
def RemoveMissingRow(dataFrame):
    dfnew = dataFrame
    for index, row in dataFrame.iterrows():
        if(pd.isnull(row["reanalysis_relative_humidity_percent"])):
            if(pd.isnull(row["reanalysis_sat_precip_amt_mm"])):
                dfnew = dfnew.drop([index])
    
    return dfnew

# %%
x_train_df = pd.read_csv(x_train_p)
x_train_df.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            32.00                             73.365714
# ...

# %%
y_train_df = pd.read_csv(y_train_p)
y_train_df.head()
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  1990          18            4
# 1   sj  1990          19            5
# 2   sj  1990          20            4
# 3   sj  1990          21            3
# 4   sj  1990          22            6

# %%
train_df = pd.concat([x_train_df,y_train_df.iloc[:,3]], axis = 1)
train_df.head(5)
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# 0                             73.365714                         12.42
# ...

# %%
test_df = pd.read_csv(x_test_p);
test_df.head()
# Out:
#   city  year  weekofyear week_start_date  ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  2008          18      2008-04-29  -0.0189 -0.018900  0.102729
# 1   sj  2008          19      2008-05-06  -0.0180 -0.012400  0.082043
# 2   sj  2008          20      2008-05-13  -0.0015       NaN  0.151083
# 3   sj  2008          21      2008-05-20      NaN -0.019867  0.124329
# 4   sj  2008          22      2008-05-27   0.0568  0.039833  0.062267
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.091200                 78.60             298.492857  ...
# 1  0.072314                 12.56             298.475714  ...
# 2  0.091529                  3.66             299.455714  ...
# 3  0.125686                  0.00             299.690000  ...
# 4  0.075914                  0.76             299.780000  ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            25.37                             78.781429
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 25 columns):
# city                                     1456 non-null object
# year                                     1456 non-null int64
# weekofyear                               1456 non-null int64
# week_start_date                          1456 non-null object
# ndvi_ne                                  1262 non-null float64
# ndvi_nw                                  1404 non-null float64
# ndvi_se                                  1434 non-null float64
# ndvi_sw                                  1434 non-null float64
# precipitation_amt_mm                     1443 non-null float64
# reanalysis_air_temp_k                    1446 non-null float64
# reanalysis_avg_temp_k                    1446 non-null float64
# reanalysis_dew_point_temp_k              1446 non-null float64
# reanalysis_max_air_temp_k                1446 non-null float64
# ...

# %% [markdown]
# #### Total null values in each column

# %%
train_df.isnull().sum()
# Out:
# city                                       0
# year                                       0
# weekofyear                                 0
# week_start_date                            0
# ndvi_ne                                  194
# ndvi_nw                                   52
# ndvi_se                                   22
# ndvi_sw                                   22
# precipitation_amt_mm                      13
# reanalysis_air_temp_k                     10
# reanalysis_avg_temp_k                     10
# reanalysis_dew_point_temp_k               10
# reanalysis_max_air_temp_k                 10
# reanalysis_min_air_temp_k                 10
# reanalysis_precip_amt_kg_per_m2           10
# reanalysis_relative_humidity_percent      10
# reanalysis_sat_precip_amt_mm              13
# reanalysis_specific_humidity_g_per_kg     10
# reanalysis_tdtr_k                         10
# station_avg_temp_c                        43
# station_diur_temp_rng_c                   43
# ...

# %% [markdown]
# ### Test

# %% [markdown]
# #### DataSet Information

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 24 columns):
# city                                     416 non-null object
# year                                     416 non-null int64
# weekofyear                               416 non-null int64
# week_start_date                          416 non-null object
# ndvi_ne                                  373 non-null float64
# ndvi_nw                                  405 non-null float64
# ndvi_se                                  415 non-null float64
# ndvi_sw                                  415 non-null float64
# precipitation_amt_mm                     414 non-null float64
# reanalysis_air_temp_k                    414 non-null float64
# reanalysis_avg_temp_k                    414 non-null float64
# reanalysis_dew_point_temp_k              414 non-null float64
# reanalysis_max_air_temp_k                414 non-null float64
# ...

# %% [markdown]
# #### Total null values in each column

# %%
test_df.isnull().sum()
# Out:
# city                                      0
# year                                      0
# weekofyear                                0
# week_start_date                           0
# ndvi_ne                                  43
# ndvi_nw                                  11
# ndvi_se                                   1
# ndvi_sw                                   1
# precipitation_amt_mm                      2
# reanalysis_air_temp_k                     2
# reanalysis_avg_temp_k                     2
# reanalysis_dew_point_temp_k               2
# reanalysis_max_air_temp_k                 2
# reanalysis_min_air_temp_k                 2
# reanalysis_precip_amt_kg_per_m2           2
# reanalysis_relative_humidity_percent      2
# reanalysis_sat_precip_amt_mm              2
# reanalysis_specific_humidity_g_per_kg     2
# reanalysis_tdtr_k                         2
# station_avg_temp_c                       12
# station_diur_temp_rng_c                  12
# ...

# %%
model_main_df = main_df.fillna(main_df.mean())
model_main_df.isnull().sum()
# Out:
# city                                     0
# year                                     0
# weekofyear                               0
# week_start_date                          0
# ndvi_ne                                  0
# ndvi_nw                                  0
# ndvi_se                                  0
# ndvi_sw                                  0
# precipitation_amt_mm                     0
# reanalysis_air_temp_k                    0
# reanalysis_avg_temp_k                    0
# reanalysis_dew_point_temp_k              0
# reanalysis_max_air_temp_k                0
# reanalysis_min_air_temp_k                0
# reanalysis_precip_amt_kg_per_m2          0
# reanalysis_relative_humidity_percent     0
# reanalysis_sat_precip_amt_mm             0
# reanalysis_specific_humidity_g_per_kg    0
# reanalysis_tdtr_k                        0
# station_avg_temp_c                       0
# station_diur_temp_rng_c                  0
# station_max_temp_c                       0
# ...

# %%
test_data = test_df.fillna(test_df.mean())
test_data.isnull().sum()
# Out:
# city                                     0
# year                                     0
# weekofyear                               0
# week_start_date                          0
# ndvi_ne                                  0
# ndvi_nw                                  0
# ndvi_se                                  0
# ndvi_sw                                  0
# precipitation_amt_mm                     0
# reanalysis_air_temp_k                    0
# reanalysis_avg_temp_k                    0
# reanalysis_dew_point_temp_k              0
# reanalysis_max_air_temp_k                0
# reanalysis_min_air_temp_k                0
# reanalysis_precip_amt_kg_per_m2          0
# reanalysis_relative_humidity_percent     0
# reanalysis_sat_precip_amt_mm             0
# reanalysis_specific_humidity_g_per_kg    0
# reanalysis_tdtr_k                        0
# station_avg_temp_c                       0
# station_diur_temp_rng_c                  0
# station_max_temp_c                       0
# ...

# %%
def ConvertNumericToCategory(dataFrame):
    cat_col = dataFrame.select_dtypes(include=['object']).copy()
    for x in cat_col.columns :
        dataFrame[x] = dataFrame[x].astype("category")
        dataFrame[x] = dataFrame[x].cat.codes
    return dataFrame

# %%
model_test_df = ConvertNumericToCategory(test_data)
model_test_df.head()
# Out:
#    city  year  weekofyear  week_start_date  ndvi_ne   ndvi_nw   ndvi_se  \
# 0     1  2008          18                0 -0.01890 -0.018900  0.102729
# 1     1  2008          19                1 -0.01800 -0.012400  0.082043
# 2     1  2008          20                2 -0.00150  0.126803  0.151083
# 3     1  2008          21                3  0.12605 -0.019867  0.124329
# 4     1  2008          22                4  0.05680  0.039833  0.062267
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k        ...          \
# 0  0.091200                 78.60             298.492857        ...
# 1  0.072314                 12.56             298.475714        ...
# 2  0.091529                  3.66             299.455714        ...
# 3  0.125686                  0.00             299.690000        ...
# 4  0.075914                  0.76             299.780000        ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# ...

# %% [markdown]
# #### Removing "week_start_date" column becasue too many unique values

# %%
model_main_df = model_main_df.drop(['week_start_date'], axis=1);
model_main_df.head()
# Out:
#    city  year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0     1  1990          18  0.122600  0.103725  0.198483  0.177617
# 1     1  1990          19  0.169900  0.142175  0.162357  0.155486
# 2     1  1990          20  0.032250  0.172967  0.157200  0.170843
# 3     1  1990          21  0.128633  0.245067  0.227557  0.235886
# 4     1  1990          22  0.196200  0.262200  0.251200  0.247340
#
#    precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# 0                 12.42             297.572857             297.742857
# 1                 22.82             298.211429             298.442857
# 2                 34.54             298.781429             298.878571
# 3                 15.36             298.987143             299.228571
# 4                  7.52             299.518571             299.664286
#
#       ...       reanalysis_relative_humidity_percent  \
# 0     ...                                  73.365714
# ...

# %%
model_test_df = model_test_df.drop(['week_start_date'], axis=1);
model_test_df.head()
# Out:
#    city  year  weekofyear  ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0     1  2008          18 -0.01890 -0.018900  0.102729  0.091200
# 1     1  2008          19 -0.01800 -0.012400  0.082043  0.072314
# 2     1  2008          20 -0.00150  0.126803  0.151083  0.091529
# 3     1  2008          21  0.12605 -0.019867  0.124329  0.125686
# 4     1  2008          22  0.05680  0.039833  0.062267  0.075914
#
#    precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# 0                 78.60             298.492857             298.550000
# 1                 12.56             298.475714             298.557143
# 2                  3.66             299.455714             299.357143
# 3                  0.00             299.690000             299.728571
# 4                  0.76             299.780000             299.671429
#
#          ...          reanalysis_precip_amt_kg_per_m2  \
# 0        ...                                    25.37
# ...

# %% [markdown]
# #### Spliting data into test and train set for testing model

# %%
X = model_main_df.iloc[:,:23]
Y = model_main_df.iloc[:,23]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.30, random_state=23)

# %% [markdown]
# #### Testing model

# %%
model_gbr = GradientBoostingRegressor(n_estimators=150)
model_gbr.fit(x_train, y_train)
model_gbr_result = model_gbr.predict(x_test)

mean_absolute_error(y_test, model_gbr_result)
# Out:
# 14.301703266520178

# %%
model_gbr = GradientBoostingRegressor(n_estimators=100)
model_gbr.fit(X, Y)
model_gbr_result = model_gbr.predict(case_1_test_df)
len(model_gbr_result)
# Out:
# 416

# %%
model_gbr_result = np.around(model_gbr_result)
model_gbr_result = model_gbr_result.astype(int)
len(model_gbr_result)
# Out:
# 416

# %%
submission_df = test_df[["city","year","weekofyear"]]
submission_df.head()
# Out:
#   city  year  weekofyear
# 0   sj  2008          18
# 1   sj  2008          19
# 2   sj  2008          20
# 3   sj  2008          21
# 4   sj  2008          22

# %%
submission_data = pd.concat([submission_df,pd.DataFrame(model_gbr_result, columns=['total_cases'])], axis = 1)

# %%
submission_file = r"E:\Zabdesk\Tools and Techniques\Final project\submission_8.csv"
submission_data.to_csv(submission_file, sep=',', encoding='utf-8')
submission_data.head()
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  2008          18            8
# 1   sj  2008          19            5
# 2   sj  2008          20            6
# 3   sj  2008          21            8
# 4   sj  2008          22           10

# %% [markdown]
# #### Result 27.06
